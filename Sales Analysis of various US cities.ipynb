# %% [markdown]
# # Sales Analysis

# %% [markdown]
# Importing all the necessary libraries

# %%
import pandas as pd
import os

# %% [markdown]
# Task #1. Merge all the 12 months of data into a single csv file

# %%
os.listdir("./Sales_Data")
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
all_data = pd.DataFrame()
for i in os.listdir("./Sales_Data"):
    current_data = pd.read_csv("./Sales_Data/"+i)
    all_data = pd.concat([all_data, current_data])

# %%
len(all_data)
# Out:
# 186850

# %%
all_data.shape
# Out:
# (186850, 6)

# %% [markdown]
# Saving all this data into a single csv file

# %%
all_data.to_csv("all_data.csv",index = False)

# %%
df = pd.read_csv("all_data.csv")
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %% [markdown]
# Drop rows of NaN

# %%
df[df.isna().any(axis=1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df[['Order Date']].isnull()
# Out:
#         Order Date
# 0            False
# 2            False
# 3            False
# 4            False
# 5            False
# ...            ...
# 186845       False
# 186846       False
# 186847       False
# 186848       False
# 186849       False
#
# [186305 rows x 1 columns]

# %%
df = df[df['Order Date'].str[0:2]!='Or']
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Order Date'])

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df.rename(columns = {'Date':'FullDate'}, inplace = True)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df['Date'] = df.FullDate.dt.date

# %%
df['Month'] = df.FullDate.dt.month

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %% [markdown]
# # Question : What was the best month for sales? How much was earned that month?

# %% [markdown]
# So for this first we need to have sales column, which is just price each * Quantity ordered

# %%
df['Sales'] = df['Quantity Ordered'].astype(float) * df['Price Each'].astype(float)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
result =df.groupby("Month").sum()
result
# Out:
#             Sales
# Month
# 1      1822256.73
# 2      2202022.42
# 3      2807100.38
# 4      3390670.24
# 5      3152606.75
# 6      2577802.26
# 7      2647775.76
# 8      2244467.88
# 9      2097560.13
# 10     3736726.88
# 11     3199603.20
# 12     4613443.34

# %%
df.groupby("Month").sum().max()
# Out:
# Sales    4613443.34
# dtype: float64

# %% [markdown]
# So, we can say that DECEMBER was the month with maximum earning and the earnings was 4613443.34

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months,result['Sales'])
plt.ylabel("Sales in US Dollars")
plt.xlabel("Month Number")
# Out:
# Text(0.5, 0, 'Month Number')

# %% [markdown]
# # Question 2. Which city had the highest number of sales?

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address            FullDate  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001 2019-04-19 08:46:00
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215 2019-04-07 22:30:00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001 2019-04-30 09:27:00
#
#          Date  Month   Sales
# 0  2019-04-19      4   23.90
# 2  2019-04-07      4   99.99
# ...

# %%
df['City'] = df['Purchase Address'].apply(lambda x: x.split(',')[1])

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df.City.unique()
# Out:
# array([' Dallas', ' Boston', ' Los Angeles', ' San Francisco', ' Seattle',
#        ' Atlanta', ' New York City', ' Portland', ' Austin'], dtype=object)

# %%
def get_state(x):
    return x.split(',')[2]
df['State'] = df['Purchase Address'].apply(lambda x: get_state(x))

# %%
df['StateReq'] = df['State'].apply(lambda x : x.split(' ')[1])

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df['Cityreq'] = df['City'] + df['StateReq']

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df.Cityreq.unique()
# Out:
# array([' DallasTX', ' BostonMA', ' Los AngelesCA', ' San FranciscoCA',
#        ' SeattleWA', ' AtlantaGA', ' New York CityNY', ' PortlandOR',
#        ' AustinTX', ' PortlandME'], dtype=object)

# %%
res = df.groupby('Cityreq').sum()
res
# Out:
#                    Month       Sales
# Cityreq
#  AtlantaGA        104794  2795498.58
#  AustinTX          69829  1819581.75
#  BostonMA         141112  3661642.01
#  DallasTX         104620  2767975.40
#  Los AngelesCA    208325  5452570.80
#  New York CityNY  175741  4664317.43
#  PortlandME        17144   449758.27
#  PortlandOR        70621  1870732.34
#  San FranciscoCA  315520  8262203.91
#  SeattleWA        104941  2747755.48

# %%
df.groupby('Cityreq').sum().max()
# Out:
# Month     315520.00
# Sales    8262203.91
# dtype: float64

# %%
import matplotlib.pyplot as plt
cities = [Cityreq for Cityreq,df in df.groupby('Cityreq')]
plt.bar(cities,res['Sales'])
plt.ylabel("Sales in US Dollars")
plt.xlabel("Cities")
plt.xticks(cities, rotation = 'vertical', size=8)            # San Francisco have the highest sales
plt.figure(figsize=(10,10))

# %% [markdown]
# # Question What time should we display advertisements to maximize likelihood of customers buying product?

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address            FullDate  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001 2019-04-19 08:46:00
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215 2019-04-07 22:30:00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001 2019-04-30 09:27:00
#
#          Date  Month   Sales          City      State StateReq         Cityreq
# ...

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date                  object
# Purchase Address            object
# FullDate            datetime64[ns]
# Date                        object
# Month                        int64
# Sales                      float64
# City                        object
# State                       object
# StateReq                    object
# Cityreq                     object
# dtype: object

# %%
df['Time'] = df.FullDate.dt.time

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df['Hour'] = df.FullDate.dt.hour

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df.groupby(['Hour']).count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
Hours = [Hour for Hour, df in df.groupby(['Hour'])]

plt.plot(Hours, df.groupby(['Hour']).count())
plt.xticks(Hours)
plt.grid()
plt.ylabel('Number Of Orders')
plt.xlabel('Hour')

# My recommendation for displaying advertisements would be slightly before 11am and before 7pm
# Out:
# Text(0.5, 0, 'Hour')

# %% [markdown]
# # Question 4. What products are most often sold together?

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address            FullDate  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001 2019-04-19 08:46:00
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215 2019-04-07 22:30:00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001 2019-04-30 09:27:00
#
#          Date  Month   Sales          City      State StateReq  \
# ...

# %%
reqdf = df[df['Order ID'].duplicated(keep=False)==True]
reqdf
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 18       176574                Google Phone                1        600
# 19       176574        USB-C Charging Cable                1      11.95
# 30       176585  Bose SoundSport Headphones                1      99.99
# ...         ...                         ...              ...        ...
# 186792   259303       AA Batteries (4-pack)                1       3.84
# 186803   259314            Wired Headphones                1      11.99
# 186804   259314      AAA Batteries (4-pack)                2       2.99
# 186841   259350                Google Phone                1        600
# 186842   259350        USB-C Charging Cable                1      11.95
#
#             Order Date                       Purchase Address  \
# ...

# %%
reqdf.groupby('Order ID')['Product']

# %%
reqdf['Grouped'] = reqdf.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
# Out:
# C:\Users\mahin\AppData\Local\Temp/ipykernel_11820/1844822614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reqdf['Grouped'] = reqdf.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))

# %%
reqdf
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 18       176574                Google Phone                1        600
# 19       176574        USB-C Charging Cable                1      11.95
# 30       176585  Bose SoundSport Headphones                1      99.99
# ...         ...                         ...              ...        ...
# 186792   259303       AA Batteries (4-pack)                1       3.84
# 186803   259314            Wired Headphones                1      11.99
# 186804   259314      AAA Batteries (4-pack)                2       2.99
# 186841   259350                Google Phone                1        600
# 186842   259350        USB-C Charging Cable                1      11.95
#
#             Order Date                       Purchase Address  \
# ...

# %%
reqdf[['Order ID','Grouped']]
# Out:
#        Order ID                                            Grouped
# 3        176560                      Google Phone,Wired Headphones
# 4        176560                      Google Phone,Wired Headphones
# 18       176574                  Google Phone,USB-C Charging Cable
# 19       176574                  Google Phone,USB-C Charging Cable
# 30       176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# ...         ...                                                ...
# 186792   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803   259314            Wired Headphones,AAA Batteries (4-pack)
# 186804   259314            Wired Headphones,AAA Batteries (4-pack)
# 186841   259350                  Google Phone,USB-C Charging Cable
# 186842   259350                  Google Phone,USB-C Charging Cable
#
# [14649 rows x 2 columns]

# %%
df2 = reqdf[['Order ID','Grouped']].drop_duplicates()
df2
# Out:
#        Order ID                                            Grouped
# 3        176560                      Google Phone,Wired Headphones
# 18       176574                  Google Phone,USB-C Charging Cable
# 30       176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32       176586                AAA Batteries (4-pack),Google Phone
# 119      176672      Lightning Charging Cable,USB-C Charging Cable
# ...         ...                                                ...
# 186781   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 186783   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 186791   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803   259314            Wired Headphones,AAA Batteries (4-pack)
# 186841   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# # What are the products which sold the most? Why do you think it sold the most?

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address            FullDate  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001 2019-04-19 08:46:00
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215 2019-04-07 22:30:00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001 2019-04-12 14:38:00
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001 2019-04-30 09:27:00
#
#          Date  Month   Sales          City      State StateReq  \
# ...

# %%
df['Quantity'] = df['Quantity Ordered'].astype(int)

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date                  object
# Purchase Address            object
# FullDate            datetime64[ns]
# Date                        object
# Month                        int64
# Sales                      float64
# City                        object
# State                       object
# StateReq                    object
# Cityreq                     object
# Time                        object
# Hour                         int64
# Quantity                     int32
# dtype: object

# %%
df.groupby('Product')['Quantity'].sum()
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity, dtype: int32

# %%
quantity_ordered = df.groupby('Product')['Quantity'].sum()

# %%
product_group = df.groupby('Product')
quantity_ordered = product_group['Quantity'].sum()

keys = [Product for Product, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.ylabel("Quantity ordered")
plt.xlabel("Products")
plt.show()                                           # Batteries are sold the most

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date                  object
# Purchase Address            object
# FullDate            datetime64[ns]
# Date                        object
# Month                        int64
# Sales                      float64
# City                        object
# State                       object
# StateReq                    object
# Cityreq                     object
# Time                        object
# Hour                         int64
# Quantity                     int32
# dtype: object

# %%
df['Price of each'] = df['Price Each'].astype(float)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
prices = df.groupby('Product')['Price of each'].mean()

# %%
#plotting the graph to show the corelation between quantity ordered and price 
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(keys, rotation='vertical', size=8)

fig.show()
# Out:
# C:\Users\mahin\AppData\Local\Temp/ipykernel_11820/1776558852.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(keys, rotation='vertical', size=8)
# C:\Users\mahin\AppData\Local\Temp/ipykernel_11820/1776558852.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
